# %% [markdown]
# # Project Name: Analyzing Netflix dataset using Python
#
# This Netflix Dataset has information about the TV Shows and Movies on Netflix till 2021.<br>
# This dataset is collected from Flixable which is a third-party Netflix search engine, and available on Kaggle website for free.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'Netflix Dataset.csv')

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size # total no. of elements(values) in the dataset
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info() # to show indexes, columns, data-types of each column, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
# Show_Id         7789 non-null object
# Category        7789 non-null object
# Title           7789 non-null object
# Director        5401 non-null object
# Cast            7071 non-null object
# Country         7282 non-null object
# Release_Date    7779 non-null object
# Rating          7782 non-null object
# Duration        7789 non-null object
# Type            7789 non-null object
# Description     7789 non-null object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### 1. Find any duplicate record if present in the dataset and remove it.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df[df.duplicated()] # to show duplicate records
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# The above two records are duplicate.

# %%
df.drop_duplicates(inplace=True) # removing duplicate records

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# It now shows two less rows in the dataset.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# Since, the duplicates are deleted, the above line of code does not give any output.

# %% [markdown]
# ### 2. Is there any Null value present in any column? Show with the Heat-map.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# ### Q1. For 'House of Cards', what is the show id and who is the director of this show ?

# %%
df[df.Title == 'House of Cards'].Show_Id
# Out:
# 2832    s2833
# Name: Show_Id, dtype: object

# %%
df[df.Title.isin(['House of Cards'])].Director
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %%
df[df.Title == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q2. In which year highest number of TV shows and Movies were released ? Show with Bar graph.

# %%
df['Date'] = pd.to_datetime(df.Release_Date)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date            datetime64[ns]
# dtype: object

# %%
df.insert(7, 'Year', df.Date.dt.year)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date    Year Rating   Duration  \
# 0    August 14, 2020  2020.0  TV-MA  4 Seasons
# 1  December 23, 2016  2016.0  TV-MA     93 min
# 2  December 20, 2018  2018.0      R     78 min
# 3  November 16, 2017  2017.0  PG-13     80 min
# ...

# %%
df.Year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
df.Year.value_counts().plot(kind = 'bar', color = 'r',figsize = (6,6))

# %% [markdown]
# ### Q3. How many Movies & TV Shows are in the dataset ? Show with the Bar Graph

# %%
df.Category.value_counts()
# we can also use >>> df.groupby('Category').Category.count()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(df.Category)

# %% [markdown]
# ### Q4. Show all the Movies that were released in year 2020.

# %%
df[(df.Year == 2020) & (df.Category == 'Movie')]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ### Q5. Show only the Titles of all TV Shows that were released in India only.

# %%
df[(df.Category == 'TV Show') & (df.Country == 'India')].Title
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q6. Show Top 10 directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
df.Director.value_counts().head(10).plot.bar(figsize = (8,6), color = 'c')

# %% [markdown]
# ### Q7. Show all the Records where "Category is Movie and type is Comedies" or "Country is United Kingdom".

# %%
df[df.Type == "Comedies"] # here the type is only "Comedies"
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
# There many titles whose type contains "Comedies" with other types.
df[df['Type'].str.contains('Comedies')]['Type'].value_counts()
# Out:
# Comedies, Dramas, International Movies             243
# Children & Family Movies, Comedies                 169
# Comedies, International Movies                     161
# Comedies, International Movies, Romantic Movies    139
# Comedies, Dramas, Independent Movies               101
#                                                   ...
# Comedies, Romantic Movies, Sports Movies             1
# Action & Adventure, Comedies, Horror Movies          1
# Comedies, Cult Movies, Sports Movies                 1
# TV Comedies, TV Dramas, TV Horror                    1
# British TV Shows, Docuseries, TV Comedies            1
# Name: Type, Length: 125, dtype: int64

# %%
df[((df.Category == 'Movie') & (df['Type'].str.contains('Comedies'))) | (df.Country == 'United Kingdom')]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# ### Q8. In how many movies/shows, Tom Cruise was cast ?

# %%
print('Tom Cruise was cast in',df['Cast'].str.contains('Tom Cruise').sum(),'movies/shows.')
# Out:
# Tom Cruise was cast in 2 movies/shows.

# %%
df[df['Cast'].str.contains('Tom Cruise') == True]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date    Year Rating Duration                        Type  \
# 3860  January 1, 2020  2020.0      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019  2019.0      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date
# 3860  Through chance, human action, past history and... 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %% [markdown]
# ### Q9. What are the different ratings defined by Netflix ?

# %%
for i in df.Rating.unique():
    print(i, ",", end=" ")
# Out:
# TV-MA , R , PG-13 , TV-14 , TV-PG , NR , TV-G , TV-Y , nan , TV-Y7 , PG , G , NC-17 , TV-Y7-FV , UR ,

# %%
 print('No. of different ratings is',df.Rating.nunique())
# Out:
# No. of different ratings is 14

# %% [markdown]
# ### Q9.1. How many movies got the 'TV-14' rating in Canada ?

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# The answer is 11

# %% [markdown]
# ### Q9.2. How many TV Shows got the 'R' rating after the year 2018 ?

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date    Year Rating  Duration      Type  \
# 6437  April 25, 2019  2019.0      R  1 Season  TV Shows
#
#                                             Description       Date
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %% [markdown]
# ### Q10. What is the maximium duration of a Movie/Show on Netflix ?

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df[['Minutes', 'Unit']] = df['Duration'].str.split(' ', expand = True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date    Year Rating   Duration  \
# 0    August 14, 2020  2020.0  TV-MA  4 Seasons
# 1  December 23, 2016  2016.0  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date Minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14       4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23      93
#
#       Unit
# 0  Seasons
# 1      min

# %%
df['Minutes'] = pd.to_numeric(df['Minutes'])

# %%
df['Minutes'].dtype
# Out:
# dtype('int64')

# %%
df['Minutes'].max()
# Out:
# 312

# %% [markdown]
# ### Q11. Which individual country has the highest no. of TV Shows ?

# %%
df_tvshow = df[(df['Category']=='TV Show')]
df_tvshow.Country.value_counts()
# Out:
# United States                                     705
# United Kingdom                                    204
# Japan                                             157
# South Korea                                       147
# India                                              71
#                                                  ...
# Croatia                                             1
# Ireland, Canada, United States, United Kingdom      1
# Norway, Germany, Sweden                             1
# Spain, Germany, Denmark, United States              1
# France, United Kingdom, United States               1
# Name: Country, Length: 183, dtype: int64

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ### Q12. How can we sort the dataset by Year ?

# %%
df.sort_values(by = 'Year').head()
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#            Release_Date    Year Rating  Duration  \
# ...

# %%
df.sort_values(by = 'Year', ascending = False).head()
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# ...

# %% [markdown]
# ### Q13. Find all the instances where:
# ### Category is "Movie" and Type is "Dramas"
# ### or
# ### Category is "TV Show" and Type is "Kids TV"

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']=='Kids TV')].head()
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
# 295    s296    Movie          Across Grace Alley   Ralph Macchio
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
# 295  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...          United States
#
#           Release_Date    Year Rating Duration    Type  \
# ...
